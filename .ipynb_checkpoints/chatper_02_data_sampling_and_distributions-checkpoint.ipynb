# %%
import warnings
import pandas            as pd
import numpy             as np
import seaborn           as sns
import scipy
import matplotlib.pyplot as plt 

from sklearn.utils import resample

# %%
# set params
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Example: Central Limit Theorem (the tendency of sample distributions to take normal distribution)

# %% [markdown]
# Histogram of annual incomes of 1,000 loan applicants (top), then 1,000 means of n=5 applicants (middle), and finally 1,000 means of n=20 applicants (bottom).

# %%
# load data
loans_income = pd.read_csv('data/loans_income.csv')

# select a sample of 1k
sample_data = loans_income.sample(1000, random_state=42).reset_index(drop=True)
sample_data['type'] = 'sample'

# select 1k means of 5
sample_mean_5 = pd.DataFrame([loans_income.sample(5).mean() for _ in range(1000)]).reset_index(drop=True)
sample_mean_5['type'] = 'mean_of_5'

# select 1k means of 20
sample_mean_20 = pd.DataFrame([loans_income.sample(20).mean() for _ in range(1000)]).reset_index(drop=True)
sample_mean_20['type'] = 'mean_of_20'

# concat results
results = pd.concat([sample_data, sample_mean_5, sample_mean_20], axis=0).reset_index(drop=True)

# %%
g = sns.FacetGrid(results, col='type', height=5)
g.map(plt.hist, 'x', range=[0, 200000], bins=40)
plt.show()

# %% [markdown]
# ## Example:  The bootstrap to the median incomes of people taking out loans

# %%
results = []

for i in range(1000):
    # draw resamples
    sample = resample(loans_income)

    # Take the median of each sample
    results.append(sample.median())

results = pd.Series(results)

# %%
print('Bootstap Statistics:\n')

print(f'original: {loans_income.median()[0]}')
print('----------------')
print(f'bias: {(results.mean() - loans_income.median())[0]}')
print('----------------')
print(f'std. error: {results.std()}')
# Out:
# Bootstap Statistics:
#
# original: 62000.0
# ----------------
# bias: -90.65600000000268
# ----------------
# std. error: 244.31797096189

# %% [markdown]
# ## Bootstrap confidence interval for the annual income of loan applicants, based on a sample of 20

# %%
#n of iteractions
n_iterations = 1000

# list to store bootstap statistics
bs_stats = []

# run bootstrap and calculate statistics
for _ in range(n_iterations):
    sample = resample(loans_income)
    statistic = np.mean(sample)
    bs_stats.append(statistic)

# calculate confidence interval of 99%
ci = np.percentile(bs_stats, [0.5, 99.5])

print(f'Confidence Interval: {ci}')
# Out:
# Confidence Interval: [68388.2098622 69131.3268019]

# %% [markdown]
# 90% - Confidence Interval: **[68511.13 - 69008.22]**
# 95% - Confidence Interval: **[68464.46 - 69025.38]**
# 99% - Confidence Interval: **[68358.95 - 69169.86]**

# %% [markdown]
# ## QQ Plot - Normal Distribution

# %%
fig, axs = plt.subplots(figsize=(10, 5), nrows=1, ncols=2)

# create a normal distribuition
norm_sample = scipy.stats.norm.rvs(size=1000)

# plot distribution
axs[0].hist(norm_sample, bins=20)

# qq plot
scipy.stats.probplot(norm_sample, plot=axs[1])

plt.show()

# %% [markdown]
# All ordered values (y=axis), is the z-score (value - mean)/standard deviation

# %% [markdown]
# ## QQ Plot - Long Tailed Distribution

# %%
# load data
sp500 = pd.read_csv('data/sp500_data.csv')

# Select netflix data
nflx = sp500['NFLX'][sp500['NFLX'] > 0]
nflx = np.diff(np.log(nflx))

# set figure
fig, axs = plt.subplots(figsize=(10, 5), nrows=1, ncols=2)

# plot distribution
axs[0].hist(nflx, bins=20)

# qq plot
scipy.stats.probplot(nflx, plot=axs[1])

plt.show()

# %% [markdown]
# ## Binomial Distribution

# %% [markdown]
# If the probability of a click converting to a sale is 0.02, what is the probability of observing 0 sales in 200 clicks?

# %%
# probability mass function
r = scipy.stats.binom.pmf(0, n=200, p=0.02)
print(f'The probaility is: {round(r*100, 2)}%')
# Out:
# The probaility is: 1.76%

# %%
# cumulative distribution function
r = scipy.stats.binom.cdf(0, n=200, p=0.02)
print(f'The probaility is: {round(r*100, 2)}%')
# Out:
# The probaility is: 1.76%

# %% [markdown]
# The difference between PMF and CDF is:
#
# - **PMF**: The probability of obtaining success in a exact amount of times.
# - **CDF**: The probability of obtaining success in a number equal our smaller a certain amount of times

# %% [markdown]
# ## Poisson Distribution

# %%
# generate 100 random numbers with an average=5
scipy.stats.poisson.rvs(5, size=100)
# Out:
# array([ 6,  6,  5,  4,  3,  3,  3,  3,  4,  1,  6,  6,  6,  5,  7,  6,  4,
#        10,  3,  4,  6,  4,  6,  2, 10,  6,  5,  3,  2,  2,  3,  4,  7,  4,
#         4,  0,  4,  5,  6,  4,  5,  8,  5,  8,  6, 12,  8,  6,  1,  7, 12,
#         4,  3,  4,  3,  6,  2,  4,  3,  6,  6,  2,  4,  8,  3,  6,  2,  7,
#         2,  3,  5,  8,  6,  3,  3,  4,  4,  4,  6,  7,  5,  6,  7,  4,  6,
#         4,  6,  5,  5,  6,  3,  4,  4,  7,  3,  6,  3,  6,  3,  3])

# %%
# for a lambda = 5, what is the probability of obtaining 3 events
lamb = 5

# pmf
value1 = 3
scipy.stats.poisson.pmf(lamb, value1)
# Out:
# 0.10081881344492458

# %%
# for a lambda = 5, what is the probability of obtaining 5 or less events
# cdf
value2 = 5
scipy.stats.poisson.pmf(lamb, value2)
# Out:
# 0.17546736976785068

# %% [markdown]
# ## EXPONENTIAL DISTRIBUTION

# %%
# generate random numbers from exponential distribution, with a rate of 0.2)
scipy.stats.expon.rvs(0.2, size=100)
# Out:
# array([0.90102775, 1.34693058, 0.28094662, 1.08042029, 0.29259555,
#        4.65140966, 4.89491289, 0.6914913 , 1.36895755, 0.21698131,
#        0.88636324, 3.08302671, 0.45596992, 0.32324553, 0.84903641,
#        1.69329242, 0.82503203, 3.30130813, 1.78842543, 0.59320388,
#        0.4579442 , 0.25252121, 0.38171459, 0.68174932, 0.77545933,
#        0.31264838, 3.01775949, 0.23578736, 1.04087274, 0.36682238,
#        0.81832277, 0.54502662, 1.42245222, 0.53110375, 0.65120846,
#        2.26976766, 0.50774956, 1.26524989, 0.60142045, 1.19698929,
#        0.7083079 , 1.13203884, 0.71097167, 5.13946054, 1.97752978,
#        1.10743389, 0.35001681, 0.98391175, 0.71638843, 1.28652664,
#        0.75719897, 0.57310189, 0.44222307, 0.39385678, 0.77691413,
#        0.36301624, 0.30914175, 0.90490037, 1.44576933, 0.20641266,
#        0.47315352, 1.13963002, 2.84873688, 1.94565008, 1.54985629,
#        0.88189259, 0.61429302, 0.83334646, 2.10656839, 0.69827457,
#        0.21652772, 1.02728788, 0.50342207, 0.36730222, 0.9618278 ,
#        1.3174045 , 3.29608681, 2.91849082, 0.99376918, 0.8125306 ,
#        0.77307329, 0.94646572, 0.30941103, 0.96279213, 0.85640975,
#        0.84908313, 0.21370197, 3.76032771, 4.42356814, 1.36193793,
#        1.25433546, 0.57357182, 0.43846278, 0.5303678 , 2.44718938,
#        1.23075564, 1.71845101, 0.62567343, 1.90547128, 0.33738087])

# %%
# calculate exponential distribution

lambbda = 0.5
sample = np.random.exponential(scale=1/lambbda, size=1000)

sample[:10]
# Out:
# array([1.65159392, 1.50752818, 0.04150525, 0.19855334, 0.79860532,
#        0.32929835, 0.26766705, 0.56754552, 4.99572665, 1.39128496])

# %% [markdown]
# ## WEIBULL DISTRIBUTION

# %%
# generate random numbers from a weibull distribution, with shape of 1.5 and characteristic life of 5k
scipy.stats.weibull_min.rvs(1.5, scale=5000, size=100)
# Out:
# array([  577.77982597,  3391.16770911,  3258.55960196,  4871.7852983 ,
#         5601.14893787,  7760.49599521,  5968.09090889,  4323.92324621,
#         2534.14675786,  1288.96485044,  2822.69291289,  1018.57129006,
#         1792.60480535,  9964.61508262,  2206.78926731,   725.15157712,
#         9126.53873414,  7914.56468663,  8589.6505281 ,  8469.72747935,
#         2094.18141999,  9346.22250569,  7293.64634168,  5236.45653545,
#        13975.8950032 ,  8090.52452781,  3595.72578226,   716.76999075,
#         1816.34636411,  3032.58667368, 10301.37893554,  4380.009782  ,
#         5209.16019621,  3329.97663332,  3580.90044007,  5160.92627762,
#         3622.04509689,  2520.61065632,  2899.20528125,  2083.11931309,
#         4717.34265824,   147.86856727,  2425.87886503,  5882.7035443 ,
#         3043.39191087,  4910.1052216 ,  1623.01041766,  1911.23774387,
#         3199.81498148,  4228.88595455,  2611.96822907,  2947.39781529,
#         1136.64793069,  3698.33478387,  1174.17023641,  3732.63810927,
#         4465.26652835,  1448.97296016,   727.25904223,  3284.11742791,
#         6706.54142521,  5854.2588099 ,  3471.61931822,  1439.17267134,
#         7152.35780044,  3811.10073459,  7298.03612312,  2565.53680013,
#          847.2570944 ,  1485.80442007,  3498.90513894,   870.09972065,
#         2102.90681383,  2523.94435084,  4829.97694306,  5009.32524195,
#         1804.24106152, 10547.23634215,  1203.65866776,  2032.67966785,
#         4283.15226467,  1393.82342592,  4318.42277265,  1195.59107765,
#         4759.68528547,  7276.37266666,  1150.9333151 ,  1527.36952554,
#         2458.3750394 ,  6042.71455334,  4009.49129506,  2293.90399157,
#         1032.98714098,  5445.66867042,  3420.13451334,  5035.41972236,
#         7306.4563487 ,  3719.5725533 ,  7211.36129261,  3788.57944415])

# %%
# calculate pdf (exact)
alpha = 2 # form parameter
beta = 3 # scale parameter
value = 4

pdf = scipy.stats.weibull_min.pdf(value, alpha, beta)
pdf
# Out:
# 0.7357588823428848

# %%
# calculate cdf (cumulative)
cdf = scipy.stats.weibull_min.pdf(value, alpha, beta)
cdf
# Out:
# 0.7357588823428848
